# %% [markdown]
# #### Data

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from time import time
from tqdm import tqdm_notebook as tqdm
import datetime

# %%
train = pd.read_csv('./train/train.csv')

# %%
view_log = pd.read_csv('./train/view_log.csv')

# %%
item_data = pd.read_csv('./train/item_data.csv')

# %%
test = pd.read_csv('./test/test.csv')

# %%
def label_encode(df_train,df_test):
    for col in list(df_train.columns):
        if col in ['impression_id','impression_time']:
            continue
        if df_train[col].dtype=='object':
            try:
                lbenc = LabelEncoder()
                lbenc.fit(df_train[col])
                df_train[col] = pd.Series(lbenc.transform(df_train[col].values))
                df_test[col] = pd.Series(lbenc.transform(df_test[col].values))
            except:
                print(col)
                raise ValueError('Erro')
    return df_train, df_test

# %%
def find_time_of_day(x):
    y = int(x.split()[1].split(':')[0])
    if y > 8 and y < 12 :
        return 0
    elif y > 12 and y < 18 :
        return 1
    elif y > 18 and y < 23:
        return 2
    else:
        return 3

# %%
def cleaning(df):
    df['month'] = df['impression_time'].apply(lambda x: int(x.split()[0].split('-')[1]))
    df['day'] = df['impression_time'].apply(lambda x: int(x.split()[0].split('-')[2]))
    df['time_of_day'] = df['impression_time'].apply(find_time_of_day)
    return df

# %%
train = cleaning(train)
test = cleaning(test)

# %%
train.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click  month  day  time_of_day
# 0           old      0         0     11   15            3
# 1        latest      1         1     11   15            3
# 2  intermediate      1         0     11   15            3
# 3        latest      1         0     11   15            3
# 4        latest      0         0     11   15            3

# %%
item_data.head()
# Out:
#    item_id  item_price  category_1  category_2  category_3  product_type
# 0    26880        4602          11          35          20          3040
# 1    54939        3513          12          57          85          6822
# 2    40383         825          17           8         279          1619
# 3     8777        2355          13          58         189          5264
# 4   113705        1267          17          39         151         10239

# %%
view_log.head()
# Out:
#            server_time device_type  session_id  user_id  item_id
# 0  2018-10-15 08:58:00     android      112333     4557    32970
# 1  2018-10-15 08:58:00     android      503590    74788     7640
# 2  2018-10-15 08:58:00     android      573960    23628   128855
# 3  2018-10-15 08:58:00     android      121691     2430    12774
# 4  2018-10-15 08:58:00     android      218564    19227    28296

# %%
test.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  a9e7126a585a69a32bc7414e9d0c0ada  2018-12-13 07:44:00    44754       127
# 1  caac14a5bf2ba283db7708bb34855760  2018-12-13 07:45:00    29656        44
# 2  13f10ba306a19ce7bec2f3cae507b698  2018-12-13 07:46:00    25234       296
# 3  39c4b4dc0e9701b55a0a4f072008fb3f  2018-12-13 07:47:00    22988       207
# 4  bf5a572cca75f5fc67f4b14e58b11d70  2018-12-13 07:48:00    35431       242
#
#   os_version  is_4G  month  day  time_of_day
# 0     latest      1     12   13            3
# 1     latest      0     12   13            3
# 2     latest      1     12   13            3
# 3     latest      1     12   13            3
# 4     latest      1     12   13            3

# %%
test.shape
# Out:
# (90675, 9)

# %%
merged_data = view_log.merge(item_data,how='left',on='item_id')

# %%
train.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click  month  day  time_of_day
# 0           old      0         0     11   15            3
# 1        latest      1         1     11   15            3
# 2  intermediate      1         0     11   15            3
# 3        latest      1         0     11   15            3
# 4        latest      0         0     11   15            3

# %%
merged_data.head()
# Out:
#            server_time device_type  session_id  user_id  item_id  item_price  \
# 0  2018-10-15 08:58:00     android      112333     4557    32970     54685.0
# 1  2018-10-15 08:58:00     android      503590    74788     7640      1376.0
# 2  2018-10-15 08:58:00     android      573960    23628   128855      4544.0
# 3  2018-10-15 08:58:00     android      121691     2430    12774       904.0
# 4  2018-10-15 08:58:00     android      218564    19227    28296      2304.0
#
#    category_1  category_2  category_3  product_type
# 0        16.0        56.0       253.0        3184.0
# 1         7.0        71.0       228.0         545.0
# 2         4.0        38.0        62.0        5609.0
# 3        17.0        39.0       252.0        2740.0
# 4        12.0        57.0        54.0        7422.0

# %%
gp = merged_data.groupby('user_id')

# %%
cat_1 = merged_data.groupby('user_id')['category_1'].agg(pd.Series.mode)

# %%
prod = merged_data.groupby('user_id')['product_type'].agg(pd.Series.mode)

# %%
def feat_engg(df_train, df_test):
    mean_ = pd.DataFrame(merged_data.groupby('user_id')['item_price'].agg(np.mean))
    max_ = pd.DataFrame(merged_data.groupby('user_id')['item_price'].agg(np.max))
    min_ = pd.DataFrame(merged_data.groupby('user_id')['item_price'].agg(np.min))
    # mode_ = pd.DataFrame(merged_data.groupby('user_id')['device_type'].agg(pd.Series.mode))
    df_train = df_train.merge(mean_,how='left',on='user_id')
    df_train = df_train.merge(max_,how='left',on='user_id')
    df_train = df_train.merge(min_,how='left',on='user_id')
    # df_train = df_train.merge(mode_,how='left',on='user_id')
    df_test = df_test.merge(mean_,how='left',on='user_id')
    df_test = df_test.merge(max_,how='left',on='user_id')
    df_test = df_test.merge(min_,how='left',on='user_id')
    # df_test = df_test.merge(mode_,how='left',on='user_id')
    return df_train, df_test

# %%
train,test = feat_engg(train,test)

# %%
train.dtypes
# Out:
# impression_id       object
# impression_time     object
# user_id              int64
# app_code             int64
# os_version          object
# is_4G                int64
# is_click             int64
# month                int64
# day                  int64
# time_of_day          int64
# item_price_x       float64
# item_price_y       float64
# item_price         float64
# dtype: object

# %%
train,test = label_encode(train,test)

# %%
train.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
#
#    os_version  is_4G  is_click  month  day  time_of_day  item_price_x  \
# 0           2      0         0     11   15            3   2350.000000
# 1           1      1         1     11   15            3   4452.833333
# 2           0      1         0     11   15            3   1598.500000
# 3           1      1         0     11   15            3   9963.388889
# 4           1      0         0     11   15            3   8618.934783
#
#    item_price_y  item_price
# 0        2350.0      2350.0
# 1       14166.0      1024.0
# 2        2224.0       973.0
# 3       93568.0       249.0
# 4      117376.0       288.0

# %%
train.shape
# Out:
# (237609, 13)

# %%
test.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  a9e7126a585a69a32bc7414e9d0c0ada  2018-12-13 07:44:00    44754       127
# 1  caac14a5bf2ba283db7708bb34855760  2018-12-13 07:45:00    29656        44
# 2  13f10ba306a19ce7bec2f3cae507b698  2018-12-13 07:46:00    25234       296
# 3  39c4b4dc0e9701b55a0a4f072008fb3f  2018-12-13 07:47:00    22988       207
# 4  bf5a572cca75f5fc67f4b14e58b11d70  2018-12-13 07:48:00    35431       242
#
#    os_version  is_4G  month  day  time_of_day  item_price_x  item_price_y  \
# 0           1      1     12   13            3  23424.000000       23424.0
# 1           1      0     12   13            3  10752.375000       54681.0
# 2           1      1     12   13            3   4974.555556       20309.0
# 3           1      1     12   13            3  15009.297297       62976.0
# 4           1      1     12   13            3   8778.285714       43392.0
#
#    item_price
# 0     23424.0
# 1       207.0
# 2      1238.0
# 3       249.0
# 4       435.0

# %%
test.shape
# Out:
# (90675, 12)

# %%
train.drop(['impression_id','impression_time'],axis=1,inplace=True)
test_impression_id = test.impression_id.values
test.drop(['impression_id','impression_time'],axis=1,inplace=True)

# %%
print(train.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237609 entries, 0 to 237608
# Data columns (total 11 columns):
# user_id         237609 non-null int64
# app_code        237609 non-null int64
# os_version      237609 non-null int64
# is_4G           237609 non-null int64
# is_click        237609 non-null int64
# month           237609 non-null int64
# day             237609 non-null int64
# time_of_day     237609 non-null int64
# item_price_x    237606 non-null float64
# item_price_y    237606 non-null float64
# item_price      237606 non-null float64
# dtypes: float64(3), int64(8)
# memory usage: 21.8 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90675 entries, 0 to 90674
# Data columns (total 10 columns):
# user_id         90675 non-null int64
# app_code        90675 non-null int64
# os_version      90675 non-null int64
# is_4G           90675 non-null int64
# month           90675 non-null int64
# day             90675 non-null int64
# time_of_day     90675 non-null int64
# item_price_x    90672 non-null float64
# item_price_y    90672 non-null float64
# item_price      90672 non-null float64
# dtypes: float64(3), int64(7)
# memory usage: 7.6 MB
# None

# %% [markdown]
# #### Model

# %%
X_train, X_val, y_train, y_val = train_test_split(train.drop(['is_click'],axis=1).values,
                                                train.is_click.values,
                                                test_size = 0.5,
                                                random_state=42,
                                                shuffle=True)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((118804, 10), (118805, 10), (118804,), (118805,))

# %%
values,counts = np.unique(y_train, return_counts=True)
print('\ty_train:\n',list(zip(values,counts)))
values,counts = np.unique(y_val, return_counts=True)
print('\ty_val:\n',list(zip(values,counts)))
# Out:
# 	y_train:
#  [(0, 113389), (1, 5415)]
# 	y_val:
#  [(0, 113358), (1, 5447)]

# %%
_start = time()
d_train = lgb.Dataset(X_train, label=y_train)
d_val = lgb.Dataset(X_val, label=y_val)
#d_train = lgb.Dataset(train.drop(['is_click'],axis=1).values, label=train.is_click.values)
params = {}
params['learning_rate'] = 0.01
params['boosting_type'] = 'gbdt'
params['objective'] = 'binary'
params['metric'] = 'auc'
params['sub_feature'] = 0.8
params['num_leaves'] = 50
params['min_data'] = 50
params['max_depth'] = 10
model = lgb.train(params, train_set=d_train, valid_sets=d_val, num_boost_round=300)
print('Training took {} sec'.format(time()-_start))
# Out:
# [1]	valid_0's auc: 0.568336
# [2]	valid_0's auc: 0.570708
# [3]	valid_0's auc: 0.575133
# [4]	valid_0's auc: 0.657814
# [5]	valid_0's auc: 0.678952
# [6]	valid_0's auc: 0.672855
# [7]	valid_0's auc: 0.679923
# [8]	valid_0's auc: 0.682636
# [9]	valid_0's auc: 0.687383
# [10]	valid_0's auc: 0.688681
# [11]	valid_0's auc: 0.689133
# [12]	valid_0's auc: 0.6894
# [13]	valid_0's auc: 0.691162
# [14]	valid_0's auc: 0.691087
# [15]	valid_0's auc: 0.691499
# [16]	valid_0's auc: 0.691827
# [17]	valid_0's auc: 0.692892
# [18]	valid_0's auc: 0.693348
# [19]	valid_0's auc: 0.693646
# [20]	valid_0's auc: 0.693994
# [21]	valid_0's auc: 0.694869
# [22]	valid_0's auc: 0.695443
# [23]	valid_0's auc: 0.695178
# [24]	valid_0's auc: 0.695269
# [25]	valid_0's auc: 0.695616
# [26]	valid_0's auc: 0.695381
# [27]	valid_0's auc: 0.69546
# [28]	valid_0's auc: 0.695272
# [29]	valid_0's auc: 0.695416
# [30]	valid_0's auc: 0.695291
# [31]	valid_0's auc: 0.695151
# [32]	valid_0's auc: 0.695045
# [33]	valid_0's auc: 0.694912
# [34]	valid_0's auc: 0.695533
# [35]	valid_0's auc: 0.695542
# [36]	valid_0's auc: 0.695494
# [37]	valid_0's auc: 0.695431
# [38]	valid_0's auc: 0.695706
# [39]	valid_0's auc: 0.695706
# [40]	valid_0's auc: 0.695748
# [41]	valid_0's auc: 0.696025
# [42]	valid_0's auc: 0.696023
# [43]	valid_0's auc: 0.696103
# [44]	valid_0's auc: 0.696285
# [45]	valid_0's auc: 0.696459
# [46]	valid_0's auc: 0.696528
# [47]	valid_0's auc: 0.696911
# [48]	valid_0's auc: 0.696946
# [49]	valid_0's auc: 0.69727
# [50]	valid_0's auc: 0.697434
# [51]	valid_0's auc: 0.697469
# [52]	valid_0's auc: 0.697562
# [53]	valid_0's auc: 0.697613
# [54]	valid_0's auc: 0.697714
# [55]	valid_0's auc: 0.697732
# [56]	valid_0's auc: 0.697799
# [57]	valid_0's auc: 0.698121
# [58]	valid_0's auc: 0.698482
# [59]	valid_0's auc: 0.698637
# [60]	valid_0's auc: 0.698759
# [228]	valid_0's auc: 0.705114
# [229]	valid_0's auc: 0.705114
# [230]	valid_0's auc: 0.7051
# [231]	valid_0's auc: 0.705113
# [232]	valid_0's auc: 0.705125
# [233]	valid_0's auc: 0.705172
# [234]	valid_0's auc: 0.70525
# [235]	valid_0's auc: 0.705263
# [236]	valid_0's auc: 0.705292
# [237]	valid_0's auc: 0.705316
# [238]	valid_0's auc: 0.705307
# [239]	valid_0's auc: 0.70536
# [240]	valid_0's auc: 0.705386
# [241]	valid_0's auc: 0.705386
# [242]	valid_0's auc: 0.70541
# [243]	valid_0's auc: 0.705479
# [244]	valid_0's auc: 0.705474
# [245]	valid_0's auc: 0.705494
# [246]	valid_0's auc: 0.705533
# [247]	valid_0's auc: 0.705539
# [248]	valid_0's auc: 0.705566
# [249]	valid_0's auc: 0.705541
# [250]	valid_0's auc: 0.705567
# [251]	valid_0's auc: 0.705614
# [252]	valid_0's auc: 0.705657
# [253]	valid_0's auc: 0.705697
# [254]	valid_0's auc: 0.70568
# [255]	valid_0's auc: 0.705737
# [256]	valid_0's auc: 0.705773
# [257]	valid_0's auc: 0.70576
# [258]	valid_0's auc: 0.705733
# [259]	valid_0's auc: 0.705717
# [260]	valid_0's auc: 0.705773
# [261]	valid_0's auc: 0.705802
# [262]	valid_0's auc: 0.705789
# [263]	valid_0's auc: 0.705867
# [264]	valid_0's auc: 0.705909
# [265]	valid_0's auc: 0.705929
# [266]	valid_0's auc: 0.705947
# [267]	valid_0's auc: 0.705908
# [268]	valid_0's auc: 0.705938
# [269]	valid_0's auc: 0.705961
# [270]	valid_0's auc: 0.705926
# [271]	valid_0's auc: 0.705916
# [272]	valid_0's auc: 0.705944
# [273]	valid_0's auc: 0.705932
# [274]	valid_0's auc: 0.705913
# [275]	valid_0's auc: 0.705938
# [276]	valid_0's auc: 0.705929
# [277]	valid_0's auc: 0.705922
# [278]	valid_0's auc: 0.705887
# [279]	valid_0's auc: 0.705919
# [280]	valid_0's auc: 0.705938
# [281]	valid_0's auc: 0.705976
# [282]	valid_0's auc: 0.705968
# [283]	valid_0's auc: 0.706013
# [284]	valid_0's auc: 0.706048
# [285]	valid_0's auc: 0.706056
# [286]	valid_0's auc: 0.70607
# [287]	valid_0's auc: 0.706105
# [288]	valid_0's auc: 0.706139
# [289]	valid_0's auc: 0.706152
# [290]	valid_0's auc: 0.706175
# [291]	valid_0's auc: 0.706195
# [292]	valid_0's auc: 0.706211
# [293]	valid_0's auc: 0.706219
# [294]	valid_0's auc: 0.706251
# [295]	valid_0's auc: 0.706227
# [296]	valid_0's auc: 0.706244
# [297]	valid_0's auc: 0.706253
# [298]	valid_0's auc: 0.706341
# [299]	valid_0's auc: 0.706371
# [300]	valid_0's auc: 0.706413
# Training took 7.491647958755493 sec

# %%
print(roc_auc_score(y_train,model.predict(X_train)))
# Out:
# 0.7735468191536067

# %%
print(roc_auc_score(y_val,model.predict(X_val)))
# Out:
# 0.7064130943221669

# %%
submission = pd.DataFrame()

# %%
submission['impression_id'] = test_impression_id

# %%
submission['is_click'] = model.predict(test.values)

# %%
submission.to_csv('./overfit.csv',index=False)
