# %% [markdown]
# #### Data

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from time import time
from tqdm import tqdm_notebook as tqdm
import datetime

# %%
train = pd.read_csv('./train/train.csv')

# %%
view_log = pd.read_csv('./train/view_log.csv')

# %%
item_data = pd.read_csv('./train/item_data.csv')

# %%
test = pd.read_csv('./test/test.csv')

# %%
def label_encode(df_train,df_test):
    for col in list(df_train.columns):
        if col in ['impression_id','impression_time']:
            continue
        if df_train[col].dtype == 'object':
            try:
                lbenc = LabelEncoder()
                lbenc.fit(df_train[col])
                df_train[col] = pd.Series(lbenc.transform(df_train[col].values))
                df_test[col] = pd.Series(lbenc.transform(df_test[col].values))
            except:
                print(col)
                raise ValueError('Erro')
    return df_train, df_test

# %%
def find_time_of_day(x):
    y = int(x.split()[1].split(':')[0])
    if y >= 6 and y < 10:
        return 0
    elif y >= 10 and y < 14:
        return 1
    elif y >= 14 and y < 18:
        return 2
    elif y >= 18 and y < 22:
        return 3
    elif y >= 22 and y < 2:
        return 4
    else:
        return 5

# %%
def cleaning(df):
    df['month'] = df['impression_time'].apply(lambda x: int(x.split()[0].split('-')[1]))
    df['day'] = df['impression_time'].apply(lambda x: int(x.split()[0].split('-')[2]))
    df['time_of_day'] = df['impression_time'].apply(find_time_of_day)
    return df

# %%
train = cleaning(train)
test = cleaning(test)

# %%
train.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click  month  day  time_of_day
# 0           old      0         0     11   15            5
# 1        latest      1         1     11   15            5
# 2  intermediate      1         0     11   15            5
# 3        latest      1         0     11   15            5
# 4        latest      0         0     11   15            5

# %%
item_data.head()
# Out:
#    item_id  item_price  category_1  category_2  category_3  product_type
# 0    26880        4602          11          35          20          3040
# 1    54939        3513          12          57          85          6822
# 2    40383         825          17           8         279          1619
# 3     8777        2355          13          58         189          5264
# 4   113705        1267          17          39         151         10239

# %%
view_log.head()
# Out:
#            server_time device_type  session_id  user_id  item_id
# 0  2018-10-15 08:58:00     android      112333     4557    32970
# 1  2018-10-15 08:58:00     android      503590    74788     7640
# 2  2018-10-15 08:58:00     android      573960    23628   128855
# 3  2018-10-15 08:58:00     android      121691     2430    12774
# 4  2018-10-15 08:58:00     android      218564    19227    28296

# %%
test.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  a9e7126a585a69a32bc7414e9d0c0ada  2018-12-13 07:44:00    44754       127
# 1  caac14a5bf2ba283db7708bb34855760  2018-12-13 07:45:00    29656        44
# 2  13f10ba306a19ce7bec2f3cae507b698  2018-12-13 07:46:00    25234       296
# 3  39c4b4dc0e9701b55a0a4f072008fb3f  2018-12-13 07:47:00    22988       207
# 4  bf5a572cca75f5fc67f4b14e58b11d70  2018-12-13 07:48:00    35431       242
#
#   os_version  is_4G  month  day  time_of_day
# 0     latest      1     12   13            0
# 1     latest      0     12   13            0
# 2     latest      1     12   13            0
# 3     latest      1     12   13            0
# 4     latest      1     12   13            0

# %%
test.shape
# Out:
# (90675, 9)

# %%
merged_data = view_log.merge(item_data,how='left',on='item_id')

# %%
train.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click  month  day  time_of_day
# 0           old      0         0     11   15            5
# 1        latest      1         1     11   15            5
# 2  intermediate      1         0     11   15            5
# 3        latest      1         0     11   15            5
# 4        latest      0         0     11   15            5

# %%
merged_data.head()
# Out:
#            server_time device_type  session_id  user_id  item_id  item_price  \
# 0  2018-10-15 08:58:00     android      112333     4557    32970     54685.0
# 1  2018-10-15 08:58:00     android      503590    74788     7640      1376.0
# 2  2018-10-15 08:58:00     android      573960    23628   128855      4544.0
# 3  2018-10-15 08:58:00     android      121691     2430    12774       904.0
# 4  2018-10-15 08:58:00     android      218564    19227    28296      2304.0
#
#    category_1  category_2  category_3  product_type
# 0        16.0        56.0       253.0        3184.0
# 1         7.0        71.0       228.0         545.0
# 2         4.0        38.0        62.0        5609.0
# 3        17.0        39.0       252.0        2740.0
# 4        12.0        57.0        54.0        7422.0

# %%
gp = merged_data.groupby('user_id')

# %%
cat_1 = merged_data.groupby('user_id')['category_1'].agg(pd.Series.mode)

# %%
prod = merged_data.groupby('user_id')['product_type'].agg(pd.Series.mode)

# %%
train,test = label_encode(train,test)

# %%
def feat_engg(df_train, df_test):
    mean_ = pd.Series(merged_data.groupby('user_id')['item_price'].agg(np.mean))
    max_ = pd.Series(merged_data.groupby('user_id')['item_price'].agg(np.max))
    min_ = pd.Series(merged_data.groupby('user_id')['item_price'].agg(np.min))
    # mode_ = pd.DataFrame(merged_data.groupby('user_id')['device_type'].agg(pd.Series.mode))
    df_train = df_train.merge(mean_,how='left',on='user_id')
    df_train = df_train.merge(max_,how='left',on='user_id')
    df_train = df_train.merge(min_,how='left',on='user_id')
    # df_train = df_train.merge(mode_,how='left',on='user_id')
    df_test = df_test.merge(mean_,how='left',on='user_id')
    df_test = df_test.merge(max_,how='left',on='user_id')
    df_test = df_test.merge(min_,how='left',on='user_id')
    # df_test = df_test.merge(mode_,how='left',on='user_id')
    return df_train, df_test

# %%
train,test = feat_engg(train,test)

# %%
train.dtypes
# Out:
# impression_id       object
# impression_time     object
# user_id              int64
# app_code             int64
# os_version           int64
# is_4G                int64
# is_click             int64
# month                int64
# day                  int64
# time_of_day          int64
# item_price_x       float64
# item_price_y       float64
# item_price_x       float64
# item_price_y       float64
# item_price_x       float64
# item_price_y       float64
# dtype: object

# %%
for i in train.columns:
    print(type(train[i]), i)
# Out:
# <class 'pandas.core.series.Series'> impression_id
# <class 'pandas.core.series.Series'> impression_time
# <class 'pandas.core.series.Series'> user_id
# <class 'pandas.core.series.Series'> app_code
# <class 'pandas.core.series.Series'> os_version
# <class 'pandas.core.series.Series'> is_4G
# <class 'pandas.core.series.Series'> is_click
# <class 'pandas.core.series.Series'> month
# <class 'pandas.core.series.Series'> day
# <class 'pandas.core.series.Series'> time_of_day
# <class 'pandas.core.frame.DataFrame'> item_price_x
# <class 'pandas.core.frame.DataFrame'> item_price_y
# <class 'pandas.core.frame.DataFrame'> item_price_x
# <class 'pandas.core.frame.DataFrame'> item_price_y
# <class 'pandas.core.frame.DataFrame'> item_price_x
# <class 'pandas.core.frame.DataFrame'> item_price_y

# %%
train.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
#
#    os_version  is_4G  is_click  month  day  time_of_day  item_price_x  \
# 0           2      0         0     11   15            5   2350.000000
# 1           1      1         1     11   15            5   4452.833333
# 2           0      1         0     11   15            5   1598.500000
# 3           1      1         0     11   15            5   9963.388889
# 4           1      0         0     11   15            5   8618.934783
#
#    item_price_y  item_price_x  item_price_y  item_price_x  item_price_y
# 0        2350.0        2350.0   2350.000000        2350.0        2350.0
# 1       14166.0        1024.0   4452.833333       14166.0        1024.0
# 2        2224.0         973.0   1598.500000        2224.0         973.0
# 3       93568.0         249.0   9963.388889       93568.0         249.0
# 4      117376.0         288.0   8618.934783      117376.0         288.0

# %%
train.shape
# Out:
# (237609, 16)

# %%
test.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  a9e7126a585a69a32bc7414e9d0c0ada  2018-12-13 07:44:00    44754       127
# 1  caac14a5bf2ba283db7708bb34855760  2018-12-13 07:45:00    29656        44
# 2  13f10ba306a19ce7bec2f3cae507b698  2018-12-13 07:46:00    25234       296
# 3  39c4b4dc0e9701b55a0a4f072008fb3f  2018-12-13 07:47:00    22988       207
# 4  bf5a572cca75f5fc67f4b14e58b11d70  2018-12-13 07:48:00    35431       242
#
#    os_version  is_4G  month  day  time_of_day  item_price_x  item_price_y  \
# 0           1      1     12   13            0  23424.000000       23424.0
# 1           1      0     12   13            0  10752.375000       54681.0
# 2           1      1     12   13            0   4974.555556       20309.0
# 3           1      1     12   13            0  15009.297297       62976.0
# 4           1      1     12   13            0   8778.285714       43392.0
#
#    item_price_x  item_price_y  item_price_x  item_price_y
# 0       23424.0  23424.000000       23424.0       23424.0
# 1         207.0  10752.375000       54681.0         207.0
# 2        1238.0   4974.555556       20309.0        1238.0
# 3         249.0  15009.297297       62976.0         249.0
# 4         435.0   8778.285714       43392.0         435.0

# %%
test.shape
# Out:
# (90675, 15)

# %%
train.drop(['impression_id','impression_time'],axis=1,inplace=True)
test_impression_id = test.impression_id.values
test.drop(['impression_id','impression_time'],axis=1,inplace=True)

# %%
print(train.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237609 entries, 0 to 237608
# Data columns (total 14 columns):
# user_id         237609 non-null int64
# app_code        237609 non-null int64
# os_version      237609 non-null int64
# is_4G           237609 non-null int64
# is_click        237609 non-null int64
# month           237609 non-null int64
# day             237609 non-null int64
# time_of_day     237609 non-null int64
# item_price_x    237606 non-null float64
# item_price_y    237606 non-null float64
# item_price_x    237606 non-null float64
# item_price_y    237606 non-null float64
# item_price_x    237606 non-null float64
# item_price_y    237606 non-null float64
# dtypes: float64(6), int64(8)
# memory usage: 27.2 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90675 entries, 0 to 90674
# Data columns (total 13 columns):
# user_id         90675 non-null int64
# app_code        90675 non-null int64
# os_version      90675 non-null int64
# is_4G           90675 non-null int64
# month           90675 non-null int64
# day             90675 non-null int64
# time_of_day     90675 non-null int64
# item_price_x    90672 non-null float64
# item_price_y    90672 non-null float64
# item_price_x    90672 non-null float64
# item_price_y    90672 non-null float64
# item_price_x    90672 non-null float64
# item_price_y    90672 non-null float64
# dtypes: float64(6), int64(7)
# memory usage: 9.7 MB
# None

# %% [markdown]
# #### Model

# %%
X_train, X_val, y_train, y_val = train_test_split(train.drop(['is_click'],axis=1).values,
                                                train.is_click.values,
                                                test_size = 0.5,
                                                random_state=42,
                                                shuffle=True)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((118804, 13), (118805, 13), (118804,), (118805,))

# %%
values,counts = np.unique(y_train, return_counts=True)
print('\ty_train:\n',list(zip(values,counts)))
values,counts = np.unique(y_val, return_counts=True)
print('\ty_val:\n',list(zip(values,counts)))
# Out:
# 	y_train:
#  [(0, 113389), (1, 5415)]
# 	y_val:
#  [(0, 113358), (1, 5447)]

# %%
_start = time()
d_train = lgb.Dataset(X_train, label=y_train)
d_val = lgb.Dataset(X_val, label=y_val)
# d_train = lgb.Dataset(train.drop(['is_click'],axis=1).values, label=train.is_click.values)
params = {}
params['learning_rate'] = 0.05
params['boosting_type'] = 'gbdt'
params['objective'] = 'binary'
params['metric'] = 'auc'
params['sub_feature'] = 0.8
params['num_leaves'] = 50
params['min_data'] = 50
params['max_depth'] = 15
params['bagging_fraction'] = 0.7
params['bagging_freq'] = 2
params['max_bin'] = 64
model = lgb.train(params, train_set=d_train, valid_sets=d_val, num_boost_round=300)
# [233]	valid_0's auc: 0.705734
# [234]	valid_0's auc: 0.705846
# [235]	valid_0's auc: 0.705719
# [236]	valid_0's auc: 0.705612
# [237]	valid_0's auc: 0.70559
# [238]	valid_0's auc: 0.705573
# [239]	valid_0's auc: 0.705594
# [240]	valid_0's auc: 0.705687
# [241]	valid_0's auc: 0.705733
# [242]	valid_0's auc: 0.705728
# [243]	valid_0's auc: 0.705593
# [244]	valid_0's auc: 0.705498
# [245]	valid_0's auc: 0.705741
# [246]	valid_0's auc: 0.70568
# [247]	valid_0's auc: 0.705588
# [248]	valid_0's auc: 0.70544
# [249]	valid_0's auc: 0.705421
# [250]	valid_0's auc: 0.705435
# [251]	valid_0's auc: 0.70543
# [252]	valid_0's auc: 0.705499
# [253]	valid_0's auc: 0.705459
# [254]	valid_0's auc: 0.705416
# [255]	valid_0's auc: 0.705454
# [256]	valid_0's auc: 0.705465
# [257]	valid_0's auc: 0.705468
# [258]	valid_0's auc: 0.705454
# [259]	valid_0's auc: 0.70537
# [260]	valid_0's auc: 0.705413
# [261]	valid_0's auc: 0.705246
# [262]	valid_0's auc: 0.705229
# [263]	valid_0's auc: 0.705084
# [264]	valid_0's auc: 0.704973
# [265]	valid_0's auc: 0.704975
# [266]	valid_0's auc: 0.705068
# [267]	valid_0's auc: 0.705052
# [268]	valid_0's auc: 0.70502
# [269]	valid_0's auc: 0.70508
# [270]	valid_0's auc: 0.705174
# [271]	valid_0's auc: 0.705099
# [272]	valid_0's auc: 0.705049
# [273]	valid_0's auc: 0.705123
# [274]	valid_0's auc: 0.705179
# [275]	valid_0's auc: 0.705139
# [276]	valid_0's auc: 0.705143
# [277]	valid_0's auc: 0.705083
# [278]	valid_0's auc: 0.705055
# [279]	valid_0's auc: 0.70493
# [280]	valid_0's auc: 0.704798
# [281]	valid_0's auc: 0.704764
# [282]	valid_0's auc: 0.704684
# [283]	valid_0's auc: 0.704792
# [284]	valid_0's auc: 0.704803
# [285]	valid_0's auc: 0.704758
# [286]	valid_0's auc: 0.704835
# [287]	valid_0's auc: 0.704801
# [288]	valid_0's auc: 0.704864
# [289]	valid_0's auc: 0.704907
# [290]	valid_0's auc: 0.704961
# [291]	valid_0's auc: 0.704896
# [292]	valid_0's auc: 0.704806
# [293]	valid_0's auc: 0.704797
# [294]	valid_0's auc: 0.704779
# [295]	valid_0's auc: 0.704777
# [296]	valid_0's auc: 0.704893
# [297]	valid_0's auc: 0.704855
# [298]	valid_0's auc: 0.70484
# [299]	valid_0's auc: 0.704775
# [300]	valid_0's auc: 0.704732
# Training took 6.435048341751099 sec

# %%
print(roc_auc_score(y_train,model.predict(X_train)))
# Out:
# 0.890364068937396

# %%
print(roc_auc_score(y_val,model.predict(X_val)))
# Out:
# 0.7047318141177706

# %%
submission = pd.DataFrame()

# %%
submission['impression_id'] = test_impression_id

# %%
submission['is_click'] = model.predict(test.values)

# %%
submission.to_csv('./overfit(?).csv',index=False)
